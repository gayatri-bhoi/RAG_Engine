# %%
! pip install langchain-community
! pip install pypdf
# Out:
# Requirement already satisfied: langchain-community in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (0.3.31)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (0.4.37)
# Requirement already satisfied: numpy>=1.26.2 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.78 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (0.3.80)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from aiosignal>=1.4.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (4.15.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (2.12.5)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain-community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.78->langchain-community) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: httpcore==1.* in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: certifi in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2025.11.12)
# Requirement already satisfied: anyio in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.0)
# Requirement already satisfied: h11>=0.16 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (2.41.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/bin/python3 -m pip install --upgrade pip' command.
# Requirement already satisfied: pypdf in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (6.4.2)
# Requirement already satisfied: typing_extensions>=4.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from pypdf) (4.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/bin/python3 -m pip install --upgrade pip' command.

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("Example.pdf")

# %%
loader

# %%
pages = loader.load()

# %%
pages
# Out:
# [Document(metadata={'producer': 'Acrobat PDFWriter 5.0 for Windows NT', 'creator': 'IEEE Citation Guidelines2.doc - Microsoft Word', 'creationdate': '2009-09-01T05:31:04+00:00', 'author': 'Administrator', 'moddate': '2019-05-07T09:26:44-04:00', 'title': 'IEEE Citation Guidelines2.doc', 'source': 'Example.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='How to Cite References: IEEE Documentation Style\nIEEE citation style is used primarily for electronics, engineering, telecommunications, \ncomputer science, and information technology reports. The three main parts of a \nreference are as follows:\n• Author’s name listed as first initial of first name, then full last.\n• Title of article, patent, conference paper, etc., in quotation marks.\n• Title of journal or book in italics.\nThis system allows the reader to identify the information source at a glance.  All \npunctuation, dates, and page numbers depend on the type of reference cited, so follow the \nexamples with care.  Please note this style guide is wide ranging, but not all sources are \nidentified.  Further research may be required.\nCitation Within The Text\nThe first step of the reference citation process is within the report itself. Each citation \nmust be noted within the text through use of simple sequential numbers. A number \nenclosed in square brackets, placed in the text of the report, indicates the specific \nreference.  Citations are numbered in the order in which they appear.  Once a source has \nbeen cited, the same number is used in all subsequent references in the report.  No\ndistinction is made between electronic and print sources, except in the citation reference\ndetails.\nEach reference number should be enclosed in square brackets on the same line as \nthe text, before any punctuation, with a space before the bracket.\nExamples\n“. . .end of the line for my research [13].”\n“The theory was first put forward in 1987 [1].”\n“Scholtz [2] has argued. . . .”\n“For example, see [7].”\n“Several recent studies [3, 4, 15, 22] have suggested that. . . .”\nNote:  Authors and dates do not have to be written out after the first reference; use the \nbracketed number.  Also, it is not necessary to write “in reference [2].”  Just write “in \n[2].”\nThe preferred method to cite more than one source at a time is to list each reference in its \nown brackets, then separate with a comma or dash:\n[1], [3], [5]\n[1] – [5]\nhttps://ieee-dataport.org'),
#  Document(metadata={'producer': 'Acrobat PDFWriter 5.0 for Windows NT', 'creator': 'IEEE Citation Guidelines2.doc - Microsoft Word', 'creationdate': '2009-09-01T05:31:04+00:00', 'author': 'Administrator', 'moddate': '2019-05-07T09:26:44-04:00', 'title': 'IEEE Citation Guidelines2.doc', 'source': 'Example.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content='Reference Lists\nTo finish citing sources, a numbered list of references must be provided at the end of the \npaper.  The list is comprised of the sequential enumerated citations, with details,\nbeginning with [1], and is not alphabetical.\nPage Format\n• Place references flush left\n• Single-space entries, double-space between.\n• Place number of entry at left margin, enclose in brackets.\n• Indent text of entries.\nThe following examples demonstrate the format for a variety of electronic and print \nsources.  These citations are ones in widest use.  Not everything is listed.\nElectronic Documents\nE-books\n[1] L. Bass, P. Clements, and R. Kazman, Software Architecture in Practice, 2nd ed.\nReading, MA: Addison Wesley, 2003. [E-book] Available: Safari e-book.\nArticle in Online Encyclopedia\n[2] D. Ince, “Acoustic coupler,” in A Dictionary of the Internet. Oxford University\nPress, [online document], 2001. Available: Oxford Reference Online, \nhttp://www.oxfordreference.com [Accessed: May 24, 2007].\nJournal Article Abstract (accessed from online database )\n[1] M. T. Kimour and D. Meslati, “Deriving objects from use cases in real-time\nembedded systems,” Information and Software Technology, vol. 47, no. 8, p. 533, \nJune 2005. [Abstract]. Available: ProQuest, http://www.umi.com/proquest/.\n[Accessed November 12, 2007].\nJournal Article in Scholarly Journal (published free of charge on the Internet)\n[2] A. Altun, “Understanding hypertext in the context of reading on the web: \nLanguage learners’ experience,” Current Issues in Education, vol. 6, no. 12, \nJuly, 2005. [Online serial]. Available: \nhttp://cie.ed.asu.edu/volume6/number12/. [Accessed Dec. 2, 2007].\nNewspaper Article from the Internet\n[3] C. Wilson-Clark, “Computers ranked as key literacy,” The Atlanta Journal\nConstitution, para. 3, March 29, 2007. [Online], Available: \nhttp://www.thewest.com.au. [Accessed Sept. 18, 2007].\nhttps://ieee-dataport.org'),
#  Document(metadata={'producer': 'Acrobat PDFWriter 5.0 for Windows NT', 'creator': 'IEEE Citation Guidelines2.doc - Microsoft Word', 'creationdate': '2009-09-01T05:31:04+00:00', 'author': 'Administrator', 'moddate': '2019-05-07T09:26:44-04:00', 'title': 'IEEE Citation Guidelines2.doc', 'source': 'Example.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}, page_content='Internet Documents\nProfessional Internet Site\n[1] European Telecommunications Standards Institute, “Digital Video Broadcasting \n(DVB): Implementation guide for DVB terrestrial services; transmission aspects,”\nEuropean Telecommunications Standards Institute, ETSI-TR-101, 2007. [Online]. \nAvailable: http://www.etsi.org. [Accessed: Nov. 12, 2007].\nGeneral Internet Site\n[2] J. Geralds, “Sega Ends Production of Dreamcast,” vnunet.com, para. 2, Jan. 31, \n2007. [Online]. Available: http://nli.vnunet.com/news/1116995. [Accessed Sept. \n12, 2007].\nPersonal Internet Site\n[3] G. Sussman, “Home Page-Dr. Gerald Sussman,” July, 2002. [Online]. \nAvailable: http://www.comm.edu.faculty/sussman/sussmanpage.htm.\n[Accessed Nov. 14, 2007].\nEmail\n[4] J. Aston. “RE: new location, okay?” Personal email (July 3, 2007).\nInternet Newsgroup\n[5] G. G. Gavin, “Climbing and limb torsion #3387,” USENET: sci.climb.torsion, \nAugust 19, 2007. [Accessed December 4, 2007].\nMicroform\n[6] W. D. Scott, Information Technology in the US. [Microform]. W. D. Scott & Co.,\nCanberra: Department of Science and Technology, 2004.\nComputer Game\n[7] The Hobbit: The prelude to the Lord of the Rings. [CD-ROM]. United Kingdom: \nVivendi Universal Games, 2003.\nSoftware\n[8] Thomson ISI, Endnote 7. [CD-ROM]. Berkeley, CA: ISI ResearchSoft, 2006.\nLecture\n[1] S. Bhanndahar. ECE 4321. Class Lecture, Topic: “Bluetooth can’t help you.” \nSchool of Electrical and Computer Engineering, Georgia Institute of Technology, \nAtlanta, GA, Jan. 9, 2008.\nhttps://ieee-dataport.org'),
#  Document(metadata={'producer': 'Acrobat PDFWriter 5.0 for Windows NT', 'creator': 'IEEE Citation Guidelines2.doc - Microsoft Word', 'creationdate': '2009-09-01T05:31:04+00:00', 'author': 'Administrator', 'moddate': '2019-05-07T09:26:44-04:00', 'title': 'IEEE Citation Guidelines2.doc', 'source': 'Example.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}, page_content='Print Documents\nBooks\nSingle Author\n[1] W. K. Chen, Linear Networks and Systems . Belmont, CA: Wadsworth Press, \n             2003.\nEdited Book\n[2] J. L. Spudich and B. H. Satir, Eds., Sensory Receptors and Signal Transduction.\nNew York: Wiley-Liss, 2001.\nSelection in an Edited Book\n[3] E. D. Lipson and B. D. Horwitz, “Photosensory reception and transduction,” in \nSensory Receptors and Signal Transduction, J. L. Spudich and B. H. Satir, Eds. \nNew York: Wiley-Liss, 2001, pp-1-64.\nThree or More Authors\n[4] R. Hayes, G. Pisano, and S. Wheelwright, Operations, Strategy, and Technical \nKnowledge. Hoboken, NJ: Wiley, 2007. \nBook by an Institutional or Organizational Author\n[5] Council of Biology Editors, Scientific Style and Format: The CBE Manual for\n Authors, Editors, and Publishers, 6th ed., Chicago: Cambridge University Press,\n            2006.\nManual\n[6] Bell Telephone Laboratories Technical Staff, Transmission System for \nCommunication, Bell Telephone Lab, 2005.\nApplication Note\n[7] Hewlett-Packard, Appl. Note 935, pp.25-29.\nNote:  Titles of unpublished works are not italicized or capitalized.  Capitalize only \nthe first word.\nTechnical Report\n[8] K. E. Elliott and C. M. Greene, “A local adaptive protocol,” Argonne National \nLaboratory, Argonne, France, Tech. Report. 916-1010-BB, 7 Apr. 2007.\nPatent/Standard\n[9] K. Kimura and A. Lipeles, “Fuzzy controller component,” U. S. Patent 14, \n860,040, 14 Dec., 2006.\nhttps://ieee-dataport.org'),
#  Document(metadata={'producer': 'Acrobat PDFWriter 5.0 for Windows NT', 'creator': 'IEEE Citation Guidelines2.doc - Microsoft Word', 'creationdate': '2009-09-01T05:31:04+00:00', 'author': 'Administrator', 'moddate': '2019-05-07T09:26:44-04:00', 'title': 'IEEE Citation Guidelines2.doc', 'source': 'Example.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5'}, page_content='Data Sheet\n[10] Texas Instruments, “High speed CMOS logic analog\n            multiplexers/demultiplexers,” 74HC4051 datasheet, Nov. 1997 [Revised Sept.\n            2002]. \nGovernment Publication\n[11] National Aeronautics and Space Administration, NASA Pocket Statistics.\nWashington, DC: Office of Headquarters Operations, 2007.\nPaper Published in Conference Proceedings\n[12] J. Smith, R. Jones, and K. Trello, “Adaptive filtering in data communications with\nself improved error reference,” In Proc. IEEE International Conference on \n           Wireless Communications ’04, 2004, pp. 65-68.\nPapers Presented at Conferences (unpublished)\n[13] H. A. Nimr, “Defuzzification of the outputs of fuzzy controllers,” presented at 5th\nInternational Conference on Fuzzy Systems, Cairo, Egypt, 2006.\nThesis or Dissertation (unpublished)\n[14] H. Zhang, “Delay-insensitive networks,” M. S. thesis, University of Chicago, \nChicago, IL, 2007.\nArticle in Encyclopedia, Signed\n[15] O. Singh, “Computer graphics,” in McGraw-Hill Encyclopedia of Science and\n Technology, New York: McGraw-Hill, 2007, pp. 279-291.\nJournal Articles\nArticle in Journal (paginated by annual volume)\n[8] K. A. Nelson, R. J. Davis, D. R. Lutz, and W. Smith, “Optical generation of \ntunable ultrasonic waves,” Journal of Applied Physics, vol. 53, no. 2, Feb., pp. \n1144-1149, 2002.\nArticle in Professional Journal (paginated by issue)\n[9] J. Attapangittya, “Social studies in gibberish,” Quarterly Review of Doublespeak,\nvol. 20, no. 1, pp. 9-10, 2003.\nArticle in Monthly or Bimonthly Periodical\n[10] J. Fallows, “Networking technology,” Atlantic Monthly, Jul., pp. 34-36, 2007.\nArticle in Daily, Weekly, or Biweekly Newspaper or Magazine\n[11] B. Metcalfe, “The numbers show how slowly the Internet runs today,” Infoworld,\n30 Sep., p. 34, 2006.\nhttps://ieee-dataport.org')]

# %%
pages[0]
# Out:
# Document(metadata={'producer': 'Acrobat PDFWriter 5.0 for Windows NT', 'creator': 'IEEE Citation Guidelines2.doc - Microsoft Word', 'creationdate': '2009-09-01T05:31:04+00:00', 'author': 'Administrator', 'moddate': '2019-05-07T09:26:44-04:00', 'title': 'IEEE Citation Guidelines2.doc', 'source': 'Example.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='How to Cite References: IEEE Documentation Style\nIEEE citation style is used primarily for electronics, engineering, telecommunications, \ncomputer science, and information technology reports. The three main parts of a \nreference are as follows:\n• Author’s name listed as first initial of first name, then full last.\n• Title of article, patent, conference paper, etc., in quotation marks.\n• Title of journal or book in italics.\nThis system allows the reader to identify the information source at a glance.  All \npunctuation, dates, and page numbers depend on the type of reference cited, so follow the \nexamples with care.  Please note this style guide is wide ranging, but not all sources are \nidentified.  Further research may be required.\nCitation Within The Text\nThe first step of the reference citation process is within the report itself. Each citation \nmust be noted within the text through use of simple sequential numbers. A number \nenclosed in square brackets, placed in the text of the report, indicates the specific \nreference.  Citations are numbered in the order in which they appear.  Once a source has \nbeen cited, the same number is used in all subsequent references in the report.  No\ndistinction is made between electronic and print sources, except in the citation reference\ndetails.\nEach reference number should be enclosed in square brackets on the same line as \nthe text, before any punctuation, with a space before the bracket.\nExamples\n“. . .end of the line for my research [13].”\n“The theory was first put forward in 1987 [1].”\n“Scholtz [2] has argued. . . .”\n“For example, see [7].”\n“Several recent studies [3, 4, 15, 22] have suggested that. . . .”\nNote:  Authors and dates do not have to be written out after the first reference; use the \nbracketed number.  Also, it is not necessary to write “in reference [2].”  Just write “in \n[2].”\nThe preferred method to cite more than one source at a time is to list each reference in its \nown brackets, then separate with a comma or dash:\n[1], [3], [5]\n[1] – [5]\nhttps://ieee-dataport.org')

# %%
len(pages)
# Out:
# 5

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len
)

# %%
! pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.0-cp39-abi3-macosx_14_0_arm64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 854 kB/s eta 0:00:01
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from faiss-cpu) (25.0)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/bin/python3 -m pip install --upgrade pip' command.

# %%
! pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
#      |████████████████████████████████| 488 kB 934 kB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 1.3 MB/s eta 0:00:01
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 1.3 MB/s eta 0:00:01
# Collecting huggingface-hub>=0.20.0
#   Downloading huggingface_hub-1.2.3-py3-none-any.whl (520 kB)
#      |████████████████████████████████| 520 kB 1.2 MB/s eta 0:00:01
# Collecting torch>=1.11.0
#   Using cached torch-2.8.0-cp39-none-macosx_11_0_arm64.whl (73.6 MB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from sentence-transformers) (4.15.0)
# Collecting transformers<5.0.0,>=4.41.0
#   Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Collecting Pillow
#   Downloading pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 523 kB/s eta 0:00:01
# Collecting shellingham
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting hf-xet<2.0.0,>=1.2.0
#   Using cached hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Collecting typer-slim
#   Downloading typer_slim-0.20.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 6.5 MB/s eta 0:00:011
# Requirement already satisfied: packaging>=20.9 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Requirement already satisfied: pyyaml>=5.1 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Collecting filelock
#   Using cached filelock-3.19.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: anyio in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: certifi in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: idna in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting networkx
#   Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: requests in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Collecting huggingface-hub>=0.20.0
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Using cached tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
# Collecting regex!=2019.12.17
#   Using cached regex-2025.11.3-cp39-cp39-macosx_11_0_arm64.whl (288 kB)
# Collecting safetensors>=0.4.3
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Collecting MarkupSafe>=2.0
#   Using cached markupsafe-3.0.3-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.6.2)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      |████████████████████████████████| 309 kB 3.8 MB/s eta 0:00:01
# Collecting click>=8.0.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 496 kB/s eta 0:00:01
# Installing collected packages: tqdm, hf-xet, fsspec, filelock, mpmath, MarkupSafe, huggingface-hub, tokenizers, threadpoolctl, sympy, scipy, safetensors, regex, networkx, joblib, jinja2, transformers, torch, scikit-learn, Pillow, sentence-transformers
# Successfully installed MarkupSafe-3.0.3 Pillow-11.3.0 filelock-3.19.1 fsspec-2025.10.0 hf-xet-1.2.0 huggingface-hub-0.36.0 jinja2-3.1.6 joblib-1.5.3 mpmath-1.3.0 networkx-3.2.1 regex-2025.11.3 safetensors-0.7.0 scikit-learn-1.6.1 scipy-1.13.1 sentence-transformers-5.1.2 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.22.1 torch-2.8.0 tqdm-4.67.1 transformers-4.57.3
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/akshaytamkhane/Documents/Gen_Ai /virtual_enviroments/rag_env/bin/python3 -m pip install --upgrade pip' command.

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
embedding_model_name = "all-MiniLM-L6-v2"

# %%
embedding_model_name = HuggingFaceEmbeddings(model_name=embedding_model_name)

# %%
result = vector_db.similarity_search(query=" what are three main parts of a reference ?", k=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 result = vector_db.similarity_search(query=" what are three main parts of a reference ?", k=3)
#
# NameError: name 'vector_db' is not defined
